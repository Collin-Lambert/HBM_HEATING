# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10.50, 6.00]
plt.rcParams["figure.autolayout"] = True


columns = ["Time", "Temperature_HBM", "Temperature_FPGA"]

# %%
SUFFIX = "HBM_+_RO_VALIDATION"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(0, 60)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("VALIDATION", fontsize = 20)
plt.savefig("VALIDATION.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_450"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 10)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 450", fontsize = 20)
plt.savefig("L3_HBM_450.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_450_2"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 10)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 450 2", fontsize = 20)
plt.savefig("L3_HBM_450_2.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_550"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 10)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 550", fontsize = 20)
plt.savefig("L3_HBM_550.png")
plt.show()
plt.close()

# %%
# FREEZER ON COMBINED


df_450 = pd.read_csv("raw_temperatures_L3_HBM_450_2.csv", usecols = columns)
df_550 = pd.read_csv("raw_temperatures_L3_HBM_550.csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 50)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20) 
plt.plot(df_450.Time, df_450.Temperature_HBM, color = "slategrey", label = "450 HBM")
plt.plot(df_450.Time, df_450.Temperature_FPGA, color = "darkslategrey", label = "450 FPGA")
plt.plot(df_550.Time, df_550.Temperature_HBM, color = "goldenrod", label = "550 HBM")
plt.plot(df_550.Time, df_550.Temperature_FPGA, color = "darkgoldenrod", label = "550 FPGA")
plt.legend(fontsize = 10)
plt.title("FREEZER ON TESTS", fontsize = 20)
plt.savefig("L3_FREEZER_ON_COMBINED.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_550_FREEZER_OFF"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 10)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 550 FREEZER OFF", fontsize = 20)
plt.savefig("L3_HBM_550_FREEZER_OFF.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_550_INSULATED_LONG"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 50)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 550 INSULATED LONG", fontsize = 20)
plt.savefig("L3_HBM_550_INSULATED_LONG.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_550_INSULATED"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 40)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 550 INSULATED", fontsize = 20)
plt.savefig("L3_HBM_550_INSULATED.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_450_INSULATED"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 40)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 450 INSULATED", fontsize = 20)
plt.savefig("L3_HBM_450_INSULATED.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_325_INSULATED"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 40)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM 325 INSULATED", fontsize = 20)
plt.savefig("L3_HBM_325_INSULATED.png")
plt.show()
plt.close()

# %%
# Insulated combined

df_325 = pd.read_csv("raw_temperatures_L3_HBM_325_INSULATED.csv", usecols = columns)
df_450 = pd.read_csv("raw_temperatures_L3_HBM_450_INSULATED.csv", usecols = columns)
df_550 = pd.read_csv("raw_temperatures_L3_HBM_550_INSULATED.csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 40)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_325.Time, df_325.Temperature_HBM, color = "darkgoldenrod", label = "325 HBM")
plt.plot(df_325.Time, df_325.Temperature_FPGA, color = "goldenrod", label = "325 FPGA")
plt.plot(df_450.Time, df_450.Temperature_HBM, color = "firebrick", label = "450 HBM")
plt.plot(df_450.Time, df_450.Temperature_FPGA, color = "indianred", label = "450 FPGA")
plt.plot(df_550.Time, df_550.Temperature_HBM, color = "darkgreen", label = "550 HBM")
plt.plot(df_550.Time, df_550.Temperature_FPGA, color = "seagreen", label = "550 FPGA")
plt.legend(fontsize = 10)
plt.title("INSULATED TESTS", fontsize = 20)
plt.savefig("L3_INSULATED_COMBINED.png")
plt.show()
plt.close()

# %%
SUFFIX = "COOLDOWN"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, -20)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 COOLDOWN", fontsize = 20)
plt.savefig("L3_COOLDOWN.png")
plt.show()
plt.close()

# %%
SUFFIX = "IDLE"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 5)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 IDLE", fontsize = 20)
plt.savefig("L3_IDLE.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_+_RO_550_INSULATED"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 80)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM + RO 550 INSULATED", fontsize = 20)
plt.savefig("L3_HBM_+_RO_550_INSULATED.png")
plt.show()
plt.close()

# %%
SUFFIX = "L3_HBM_+_RO_550_FREEZER_OFF"

df_VALIDATION = pd.read_csv("raw_temperatures_" + SUFFIX + ".csv", usecols = columns)

# VALIDATION
plt.ylim(-45, 80)
plt.ylabel("Temperature (℃)", fontsize = 20)
plt.xlabel("Time in Seconds", fontsize = 20)
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_HBM, color = "darkgoldenrod", label = "HBM")
plt.plot(df_VALIDATION.Time, df_VALIDATION.Temperature_FPGA, color = "darkslategrey", label = "FPGA")
plt.legend(fontsize = 15)
plt.title("L3 HBM + RO 550 FREEZER OFF", fontsize = 20)
plt.savefig("L3_HBM_+_RO_550_FREEZER_OFF.png")
plt.show()
plt.close()
